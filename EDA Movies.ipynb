# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.options.display.max_columns = 30
pd.options.display.float_format = '{:.2f}'.format

# %%
df = pd.read_csv('movies_complete.csv', parse_dates=['release_date'])

# %%
df.shape
# Out:
# (44691, 22)

# %%
df.head()
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                              tagline release_date  \
# 0                                                NaN   1995-10-30
# 1          Roll the dice and unleash the excitement!   1995-12-15
# 2  Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3  Friends are the people who let you be yourself...   1995-12-22
# 4  Just When His World Is Back To Normal... He's ...   1995-02-10
#
#                      genres           belongs_to_collection original_language  \
# 0   Animation|Comedy|Family            Toy Story Collection                en
# 1  Adventure|Fantasy|Family                             NaN                en
# 2            Romance|Comedy       Grumpy Old Men Collection                en
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44691 entries, 0 to 44690
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     44691 non-null  int64
#  1   title                  44691 non-null  object
#  2   tagline                20284 non-null  object
#  3   release_date           44657 non-null  datetime64[ns]
#  4   genres                 42586 non-null  object
#  5   belongs_to_collection  4463 non-null   object
#  6   original_language      44681 non-null  object
#  7   budget_musd            8854 non-null   float64
#  8   revenue_musd           7385 non-null   float64
#  9   production_companies   33356 non-null  object
#  10  production_countries   38835 non-null  object
#  11  vote_count             44691 non-null  float64
#  12  vote_average           42077 non-null  float64
#  13  popularity             44691 non-null  float64
# ...

# %% [markdown]
# **Features**
#
# id: The ID of the movie (clear/unique identifier).
#
# title: The Official Title of the movie.
#
# tagline: The tagline of the movie.
#
# release_date: Theatrical Release Date of the movie.
#
# genres: Genres associated with the movie.
#
# belongs_to_collection: Gives information on the movie series/franchise the particular film belongs to.
#
# original_language: The language in which the movie was originally shot in.
#
# budget_musd: The budget of the movie in million dollars.
#
# revenue_musd: The total revenue of the movie in million dollars.
#
# production_companies: Production companies involved with the making of the movie.
#
# production_countries: Countries where the movie was shot/produced in.
#
# vote_count: The number of votes by users, as counted by TMDB.
#
# vote_average: The average rating of the movie.
#
# popularity: The Popularity Score assigned by TMDB.
#
# runtime: The runtime of the movie in minutes.
#
# overview: A brief blurb of the movie.
#
# spoken_languages: Spoken languages in the film.
#
# poster_path: The URL of the poster image.
#
# cast: (Main) Actors appearing in the movie.
#
# cast_size: number of Actors appearing in the movie.
#
# director: Director of the movie.
#
# crew_size: Size of the film crew (incl. director, excl. actors).

# %%
df['genres'][1]
# Out:
# 'Adventure|Fantasy|Family'

# %%
df.describe()
# Out:
#              id  budget_musd  revenue_musd  vote_count  vote_average  \
# count  44691.00      8854.00       7385.00    44691.00      42077.00
# mean  107186.24        21.67         68.97      111.65          6.00
# std   111806.36        34.36        146.61      495.32          1.28
# min        2.00         0.00          0.00        0.00          0.00
# 25%    26033.50         2.00          2.41        3.00          5.30
# 50%    59110.00         8.20         16.87       10.00          6.10
# 75%   154251.00        25.00         67.64       35.00          6.80
# max   469172.00       380.00       2787.97    14075.00         10.00
#
#        popularity  runtime  cast_size  crew_size
# count    44691.00 43179.00   44691.00   44691.00
# mean         2.96    97.57      12.48      10.31
# std          6.04    34.65      12.12      15.89
# min          0.00     1.00       0.00       0.00
# 25%          0.40    86.00       6.00       2.00
# ...

# %%
df.hist(figsize = (20,12), bins = 100)
plt.show()

# %%
df.columns
# Out:
# Index(['id', 'title', 'tagline', 'release_date', 'genres',
#        'belongs_to_collection', 'original_language', 'budget_musd',
#        'revenue_musd', 'production_companies', 'production_countries',
#        'vote_count', 'vote_average', 'popularity', 'runtime', 'overview',
#        'spoken_languages', 'poster_path', 'cast', 'cast_size', 'crew_size',
#        'director'],
#       dtype='object')

# %%
df.budget_musd.value_counts(dropna = False).head(20)

#we could see that budget of the most of the movies were unknown
# Out:
# NaN      35837
# 5.00       286
# 10.00      258
# 20.00      243
# 2.00       241
# 15.00      226
# 3.00       220
# 25.00      206
# 1.00       195
# 30.00      189
# 4.00       180
# 6.00       173
# 12.00      171
# 40.00      166
# 8.00       155
# 35.00      141
# 0.50       141
# 7.00       137
# 50.00      124
# 1.50       119
# Name: budget_musd, dtype: int64

# %%
df.revenue_musd.value_counts(dropna=False).head(20)

#same here, lot of NaNs
# Out:
# NaN      37306
# 12.00       20
# 10.00       19
# 11.00       19
# 2.00        18
# 6.00        17
# 5.00        14
# 0.50        13
# 8.00        13
# 0.00        12
# 14.00       12
# 7.00        11
# 3.00        10
# 1.00        10
# 20.00       10
# 0.00         9
# 1.50         9
# 4.00         9
# 30.00        8
# 4.10         8
# Name: revenue_musd, dtype: int64

# %%
df.vote_average.value_counts(dropna=False).head(20)
# Out:
# NaN     2614
# 6.00    2421
# 5.00    1969
# 7.00    1859
# 6.50    1705
# 6.30    1583
# 5.50    1369
# 5.80    1358
# 6.40    1343
# 6.70    1328
# 6.80    1316
# 6.10    1274
# 6.60    1250
# 6.20    1240
# 5.90    1189
# 5.30    1068
# 5.70    1039
# 6.90    1029
# 5.60     994
# 7.30     987
# Name: vote_average, dtype: int64

# %%
df.vote_count.value_counts(dropna=False)
# Out:
# 1.00       3186
# 2.00       3056
# 3.00       2729
# 0.00       2614
# 4.00       2442
#            ...
# 2755.00       1
# 1187.00       1
# 4200.00       1
# 3322.00       1
# 2712.00       1
# Name: vote_count, Length: 1820, dtype: int64

# %%
df.describe(include = 'object')
# Out:
#              title                 tagline genres belongs_to_collection  \
# count        44691                   20284  42586                  4463
# unique       41605                   20171   4044                  1691
# top     Cinderella  Based on a true story.  Drama       The Bowery Boys
# freq            11                       7   4935                    29
#
#        original_language       production_companies      production_countries  \
# count              44681                      33356                     38835
# unique                89                      22537                      2377
# top                   en  Metro-Goldwyn-Mayer (MGM)  United States of America
# freq               31755                        741                     17723
#
#                                     overview spoken_languages  \
# count                                  43740            41094
# unique                                 43715             1828
# ...

# %% [markdown]
# # Best and Worst Movies

# %%
from IPython.display import HTML

# %%
df_best = df[['poster_path', 'title', 'budget_musd', 'revenue_musd', 'vote_average','vote_count','popularity']].copy()

# %%
df_best['profit'] = df.revenue_musd.sub(df.budget_musd)
df_best['return'] = df.revenue_musd.div(df.budget_musd)

# %%
df_best.head()
# Out:
#                                          poster_path  \
# 0  <img src='http://image.tmdb.org/t/p/w185//uXDf...
# 1  <img src='http://image.tmdb.org/t/p/w185//vgpX...
# 2  <img src='http://image.tmdb.org/t/p/w185//1FSX...
# 3  <img src='http://image.tmdb.org/t/p/w185//4wjG...
# 4  <img src='http://image.tmdb.org/t/p/w185//lf9R...
#
#                          title  budget_musd  revenue_musd  vote_average  \
# 0                    Toy Story        30.00        373.55          7.70
# 1                      Jumanji        65.00        262.80          6.90
# 2             Grumpier Old Men          NaN           NaN          6.50
# 3            Waiting to Exhale        16.00         81.45          6.10
# 4  Father of the Bride Part II          NaN         76.58          5.70
#
#    vote_count  popularity  profit  return
# 0     5415.00       21.95  343.55   12.45
# 1     2413.00       17.02  197.80    4.04
# 2       92.00       11.71     NaN     NaN
# ...

# %%
df_best.columns = ['', 'Title', 'Budget', 'Revenue', 'Average Rating', 'Votes', 'Popularity', 'Profit', 'ROI']

# %%
df_best.head()
# Out:
#                                                       \
# 0  <img src='http://image.tmdb.org/t/p/w185//uXDf...
# 1  <img src='http://image.tmdb.org/t/p/w185//vgpX...
# 2  <img src='http://image.tmdb.org/t/p/w185//1FSX...
# 3  <img src='http://image.tmdb.org/t/p/w185//4wjG...
# 4  <img src='http://image.tmdb.org/t/p/w185//lf9R...
#
#                          Title  Budget  Revenue  Average Rating   Votes  \
# 0                    Toy Story   30.00   373.55            7.70 5415.00
# 1                      Jumanji   65.00   262.80            6.90 2413.00
# 2             Grumpier Old Men     NaN      NaN            6.50   92.00
# 3            Waiting to Exhale   16.00    81.45            6.10   34.00
# 4  Father of the Bride Part II     NaN    76.58            5.70  173.00
#
#    Popularity  Profit   ROI
# 0       21.95  343.55 12.45
# 1       17.02  197.80  4.04
# 2       11.71     NaN   NaN
# 3        3.86   65.45  5.09
# 4        8.39     NaN   NaN

# %%
df_best.set_index('Title', inplace = True)

# %%
df_best.iloc[0,0]
# Out:
# "<img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'>"

# %%
df_best.head()
# Out:
#                                                                                 \
# Title
# Toy Story                    <img src='http://image.tmdb.org/t/p/w185//uXDf...
# Jumanji                      <img src='http://image.tmdb.org/t/p/w185//vgpX...
# Grumpier Old Men             <img src='http://image.tmdb.org/t/p/w185//1FSX...
# Waiting to Exhale            <img src='http://image.tmdb.org/t/p/w185//4wjG...
# Father of the Bride Part II  <img src='http://image.tmdb.org/t/p/w185//lf9R...
#
#                              Budget  Revenue  Average Rating   Votes  \
# Title
# Toy Story                     30.00   373.55            7.70 5415.00
# Jumanji                       65.00   262.80            6.90 2413.00
# Grumpier Old Men                NaN      NaN            6.50   92.00
# Waiting to Exhale             16.00    81.45            6.10   34.00
# Father of the Bride Part II     NaN    76.58            5.70  173.00
#
#                              Popularity  Profit   ROI
# ...

# %%
df.shape
# Out:
# (44691, 22)

# %%
#testing HTML format for posters
subset = df_best.iloc[:5,:2]

# %%
HTML(subset.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Budget</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Toy Story</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'></td>
#       <td>30.00</td>
#     </tr>
#     <tr>
#       <th>Jumanji</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//vgpXmVaVyUL7GGiDeiK1mKEKzcX.jpg' style='height:100px;'></td>
#       <td>65.00</td>
#     </tr>
#     <tr>
#       <th>Grumpier Old Men</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//1FSXpj5e8l4KH6nVFO5SPUeraOt.jpg' style='height:100px;'></td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Waiting to Exhale</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//4wjGMwPsdlvi025ZqR4rXnFDvBz.jpg' style='height:100px;'></td>
# ...

# %%
df_best.sort_values(by = 'Average Rating', ascending = False)
# Out:
#                                                                                                \
# Title
# Portrait of a Young Man in Three Movements                                                NaN
# Brave Revolutionary                         <img src='http://image.tmdb.org/t/p/w185//zAb2...
# Other Voices Other Rooms                    <img src='http://image.tmdb.org/t/p/w185//4ifP...
# The Lion of Thebes                          <img src='http://image.tmdb.org/t/p/w185//tdOc...
# Katt Williams: Priceless: Afterlife         <img src='http://image.tmdb.org/t/p/w185//wKrH...
# ...                                                                                       ...
# Altar of Fire                               <img src='http://image.tmdb.org/t/p/w185//iJ78...
# The Wonders of Aladdin                      <img src='http://image.tmdb.org/t/p/w185//AvfX...
# Deep Hearts                                 <img src='http://image.tmdb.org/t/p/w185//8jI4...
# ...

# %%
df_best.sort_values(by = 'ROI', ascending = False)
# Out:
#                                                                             \
# Title
# Less Than Zero           <img src='http://image.tmdb.org/t/p/w185//1GY0...
# Modern Times             <img src='http://image.tmdb.org/t/p/w185//7uoi...
# Welcome to Dongmakgol    <img src='http://image.tmdb.org/t/p/w185//5iGV...
# Aquí Entre Nos           <img src='http://image.tmdb.org/t/p/w185//oflx...
# The Karate Kid, Part II  <img src='http://image.tmdb.org/t/p/w185//mSne...
# ...                                                                    ...
# Subdue                   <img src='http://image.tmdb.org/t/p/w185//pfC8...
# Century of Birthing      <img src='http://image.tmdb.org/t/p/w185//xZkm...
# Betrayal                 <img src='http://image.tmdb.org/t/p/w185//eGga...
# Satan Triumphant         <img src='http://image.tmdb.org/t/p/w185//aorB...
# Queerama                 <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
# ...

# %%
#Now let's get the list of top movies which has the budget greater than $5M by Average Voting
df_best.loc[df_best.Budget >= 5].sort_values(by = 'Average Rating', ascending = False)
# Out:
#                                                                                 \
# Title
# Dilwale Dulhania Le Jayenge  <img src='http://image.tmdb.org/t/p/w185//2CAL...
# The Kingdom of Solomon       <img src='http://image.tmdb.org/t/p/w185//j24f...
# Human                        <img src='http://image.tmdb.org/t/p/w185//vdZg...
# The Shawshank Redemption     <img src='http://image.tmdb.org/t/p/w185//5KCV...
# The Godfather                <img src='http://image.tmdb.org/t/p/w185//iVZ3...
# ...                                                                        ...
# Antidur                      <img src='http://image.tmdb.org/t/p/w185//f5XO...
# Joe and Max                  <img src='http://image.tmdb.org/t/p/w185//1Ver...
# Honky Tonk Freeway           <img src='http://image.tmdb.org/t/p/w185//7BXc...
# Bopha!                       <img src='http://image.tmdb.org/t/p/w185//2m8w...
# Lucky Lady                   <img src='http://image.tmdb.org/t/p/w185//8FkL...
#
# ...

# %%
df_best.Budget.fillna(0, inplace = True)
df_best.Votes.fillna(0, inplace = True)

# %%
#Function which will return the required number of movies based on the given condition

def best_worst(n, by, ascending = False, min_budget=0, min_votes = 0):
  df2 = df_best.loc[(df_best.Budget >= min_budget) & (df_best.Votes >= min_votes), ['', by]].sort_values(by=by, ascending = ascending).head(n).copy()

  return HTML(df2.to_html(escape = False))

# %%
#top 10 expensive movies which are made .. from the dataset
best_worst(10, 'Budget')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Budget</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Pirates of the Caribbean: On Stranger Tides</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//keGfSvCmYj7CvdRx36OdVrAEibE.jpg' style='height:100px;'></td>
#       <td>380.00</td>
#     </tr>
#     <tr>
#       <th>Pirates of the Caribbean: At World's End</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//oVh3REsCwJwmrTkZ9OkkeKiAE02.jpg' style='height:100px;'></td>
#       <td>300.00</td>
#     </tr>
#     <tr>
#       <th>Avengers: Age of Ultron</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//4ssDuvEDkSArWEdyBl2X5EHvYKU.jpg' style='height:100px;'></td>
#       <td>280.00</td>
#     </tr>
#     <tr>
#       <th>Superman Returns</th>
# ...

# %%
#Highest ROI

best_worst(5, 'ROI', min_budget=50)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>ROI</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Minions</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tMaGZ2HR8HAFwkx4YRib0CDVfNT.jpg' style='height:100px;'></td>
#       <td>15.63</td>
#     </tr>
#     <tr>
#       <th>Jurassic Park</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//oU7Oq2kFAAlGqbU4VoAE36g4hoI.jpg' style='height:100px;'></td>
#       <td>14.60</td>
#     </tr>
#     <tr>
#       <th>The Twilight Saga: New Moon</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//j5jM5pq78ObAXX1WhTsb115EkLl.jpg' style='height:100px;'></td>
#       <td>14.20</td>
#     </tr>
#     <tr>
#       <th>Deadpool</th>
# ...

# %%
#Most Votes

best_worst(5, 'Votes')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Votes</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Inception</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9gk7adHYeDvHkCSEqAvQNLV5Uge.jpg' style='height:100px;'></td>
#       <td>14075.00</td>
#     </tr>
#     <tr>
#       <th>The Dark Knight</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//qJ2tW6WMUDux911r6m7haRef0WH.jpg' style='height:100px;'></td>
#       <td>12269.00</td>
#     </tr>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>12114.00</td>
#     </tr>
#     <tr>
#       <th>The Avengers</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//RYMX2wcKCBAr24UyPD7xwmjaTn.jpg' style='height:100px;'></td>
# ...

# %%
#Highest rating

best_worst(3, 'Average Rating')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Average Rating</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Portrait of a Young Man in Three Movements</th>
#       <td>NaN</td>
#       <td>10.00</td>
#     </tr>
#     <tr>
#       <th>Brave Revolutionary</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//zAb2YxgYSJTcloGTHAA9ogOVq7M.jpg' style='height:100px;'></td>
#       <td>10.00</td>
#     </tr>
#     <tr>
#       <th>Other Voices Other Rooms</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//4ifPBA4AjRQWxgVJAwSwWp6nFCa.jpg' style='height:100px;'></td>
#       <td>10.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Most Popular

best_worst(5, 'Popularity')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Popularity</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Minions</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tMaGZ2HR8HAFwkx4YRib0CDVfNT.jpg' style='height:100px;'></td>
#       <td>547.49</td>
#     </tr>
#     <tr>
#       <th>Wonder Woman</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//gfJGlDaHuWimErCr5Ql0I8x9QSy.jpg' style='height:100px;'></td>
#       <td>294.34</td>
#     </tr>
#     <tr>
#       <th>Beauty and the Beast</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tWqifoYuwLETmmasnGHO7xBjEtt.jpg' style='height:100px;'></td>
#       <td>287.25</td>
#     </tr>
#     <tr>
#       <th>Baby Driver</th>
# ...

# %% [markdown]
# # What's your next Movie?

# %%
df.genres
# Out:
# 0         Animation|Comedy|Family
# 1        Adventure|Fantasy|Family
# 2                  Romance|Comedy
# 3            Comedy|Drama|Romance
# 4                          Comedy
#                    ...
# 44686                Drama|Family
# 44687                       Drama
# 44688       Action|Drama|Thriller
# 44689                         NaN
# 44690                         NaN
# Name: genres, Length: 44691, dtype: object

# %% [markdown]
# ### Search1 = Let's search some Science Fiction & Action movie starring Bruce Willis

# %%
mask_genres = df.genres.str.contains('Action') & df.genres.str.contains('Science Fiction')
mask_genres
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44686    False
# 44687    False
# 44688    False
# 44689    False
# 44690    False
# Name: genres, Length: 44691, dtype: bool

# %%
df.cast
# Out:
# 0        Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wal...
# 1        Robin Williams|Jonathan Hyde|Kirsten Dunst|Bra...
# 2        Walter Matthau|Jack Lemmon|Ann-Margret|Sophia ...
# 3        Whitney Houston|Angela Bassett|Loretta Devine|...
# 4        Steve Martin|Diane Keaton|Martin Short|Kimberl...
#                                ...
# 44686              Leila Hatami|Kourosh Tahami|Elham Korda
# 44687    Angel Aquino|Perry Dizon|Hazel Orencio|Joel To...
# 44688    Erika Eleniak|Adam Baldwin|Julie du Page|James...
# 44689    Iwan Mosschuchin|Nathalie Lissenko|Pavel Pavlo...
# 44690                                                  NaN
# Name: cast, Length: 44691, dtype: object

# %%
mask_actor = df.cast.str.contains('Bruce Willis')
mask_actor
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44686    False
# 44687    False
# 44688    False
# 44689    False
# 44690      NaN
# Name: cast, Length: 44691, dtype: object

# %%
df.loc[mask_actor & mask_genres, ['title', 'vote_average']].sort_values(by = "vote_average", ascending = False)
# Out:
#                        title  vote_average
# 1448       The Fifth Element          7.30
# 19218                 Looper          6.60
# 1786              Armageddon          6.50
# 14135             Surrogates          5.90
# 20333  G.I. Joe: Retaliation          5.40
# 27619                   Vice          4.10

# %%
bruce  = df.loc[mask_actor & mask_genres, ['title', 'poster_path','vote_average']].sort_values(by = "vote_average", ascending = False)

# %%
HTML(bruce.head().to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>poster_path</th>
#       <th>vote_average</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1448</th>
#       <td>The Fifth Element</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//fPtlCO1yQtnoLHOwKtWz7db6RGU.jpg' style='height:100px;'></td>
#       <td>7.30</td>
#     </tr>
#     <tr>
#       <th>19218</th>
#       <td>Looper</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//sNjL6SqErDBE8OUZlrDLkexfsCj.jpg' style='height:100px;'></td>
#       <td>6.60</td>
#     </tr>
#     <tr>
#       <th>1786</th>
#       <td>Armageddon</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//fMtOCd0EAdAzKtGLQiHjSUvbdNc.jpg' style='height:100px;'></td>
#       <td>6.50</td>
#     </tr>
#     <tr>
#       <th>14135</th>
#       <td>Surrogates</td>
# ...

# %% [markdown]
# ### Search2 = Let's search some movies with Uma Thurman, directed by Tarantino

# %%
thurman  = df.cast.str.contains("Uma Thurman")
tarantino = df.director.str.contains('Quentin Tarantino')

# %%
search2 = df.loc[thurman & tarantino, ['title', 'poster_path', 'vote_average']].sort_values(ascending=False, by = 'vote_average')

# %%
HTML(search2.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>poster_path</th>
#       <th>vote_average</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>291</th>
#       <td>Pulp Fiction</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//d5iIlFn5s0ImszYzBPb8JPIfbXD.jpg' style='height:100px;'></td>
#       <td>8.30</td>
#     </tr>
#     <tr>
#       <th>6667</th>
#       <td>Kill Bill: Vol. 1</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//v7TaX8kXMXs5yFFGR41guUDNcnB.jpg' style='height:100px;'></td>
#       <td>7.70</td>
#     </tr>
#     <tr>
#       <th>7208</th>
#       <td>Kill Bill: Vol. 2</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//2yhg0mZQMhDyvUQ4rG1IZ4oIA8L.jpg' style='height:100px;'></td>
#       <td>7.70</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Search3 = Most successful Pixar Studios Movies between 2010 and 2015 (Highest Revenue)

# %%
df.production_companies
# Out:
# 0                                  Pixar Animation Studios
# 1        TriStar Pictures|Teitler Film|Interscope Commu...
# 2                              Warner Bros.|Lancaster Gate
# 3                   Twentieth Century Fox Film Corporation
# 4                Sandollar Productions|Touchstone Pictures
#                                ...
# 44686                                                  NaN
# 44687                                          Sine Olivia
# 44688                              American World Pictures
# 44689                                            Yermoliev
# 44690                                                  NaN
# Name: production_companies, Length: 44691, dtype: object

# %%
mask_studio = df.production_companies.str.contains('Pixar').fillna(False)

# %%
type(df['release_date'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
mask_release_dates = df.release_date.between('2010-01-01', '2015-12-31')

# %%
search3 = df.loc[mask_studio & mask_release_dates, ['title', 'poster_path', 'revenue_musd', 'release_date']].sort_values(ascending = False, by = 'revenue_musd')

# %%
#top 5

HTML(search3.head().to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>poster_path</th>
#       <th>revenue_musd</th>
#       <th>release_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>15236</th>
#       <td>Toy Story 3</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//amY0NH1ksd9xJ9boXAMmods6U0D.jpg' style='height:100px;'></td>
#       <td>1066.97</td>
#       <td>2010-06-16</td>
#     </tr>
#     <tr>
#       <th>29957</th>
#       <td>Inside Out</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//lRHE0vzf3oYJrhbsHXjIkF4Tl5A.jpg' style='height:100px;'></td>
#       <td>857.61</td>
#       <td>2015-06-09</td>
#     </tr>
#     <tr>
#       <th>20888</th>
#       <td>Monsters University</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//tyHHjZEzJutWggujN1KP0a1jfLX.jpg' style='height:100px;'></td>
#       <td>743.56</td>
#       <td>2013-06-20</td>
#     </tr>
# ...

# %% [markdown]
# ### Search4 = Action / Thriller movies with orginal lang Eng, and min rating of 7.5 (most recent)

# %%
mask_genre = df.genres.str.contains('Action') | df.genres.str.contains('Thriller')
mask_lang = df.original_language == 'en'
mask_rating = df.vote_average >= 7.5
mask_vote_count = df.vote_count >= 10

# %%
search4 = df.loc[mask_genre & mask_lang & mask_rating & mask_vote_count,
                 ['title', 'poster_path', 'vote_average','vote_count','release_date']].sort_values(ascending = False, by = 'release_date').set_index('title')

# %%
HTML(search4.head().to_html(escape = False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>vote_average</th>
#       <th>vote_count</th>
#       <th>release_date</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Descendants 2</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//8BNyZlBk4Hs92z6UrvFDjvx3yMb.jpg' style='height:100px;'></td>
#       <td>7.50</td>
#       <td>171.00</td>
#       <td>2017-07-21</td>
#     </tr>
#     <tr>
#       <th>Dunkirk</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//ebSnODDg9lbsMIaWg2uAbjn7TO5.jpg' style='height:100px;'></td>
#       <td>7.50</td>
#       <td>2712.00</td>
#       <td>2017-07-19</td>
#     </tr>
#     <tr>
#       <th>The Book of Henry</th>
# ...

# %% [markdown]
# ## Let's find out the common Words used in Movie Titles and Taglines

# %%
from wordcloud import WordCloud

# %%
' '.join(df.title[0])
# Out:
# 'T o y   S t o r y'

# %%
df.head()
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                              tagline release_date  \
# 0                                                NaN   1995-10-30
# 1          Roll the dice and unleash the excitement!   1995-12-15
# 2  Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3  Friends are the people who let you be yourself...   1995-12-22
# 4  Just When His World Is Back To Normal... He's ...   1995-02-10
#
#                      genres           belongs_to_collection original_language  \
# 0   Animation|Comedy|Family            Toy Story Collection                en
# 1  Adventure|Fantasy|Family                             NaN                en
# 2            Romance|Comedy       Grumpy Old Men Collection                en
# ...

# %%
title = df.title.dropna()
tagline = df.tagline.dropna()
overview = df.overview.dropna()

# %%
title_corpus = ' '.join(title)
tagline_corpus = ' '.join(tagline)
overview_corpus = ' '.join(overview)

# %%
type(title_corpus)
# Out:
# str

# %%
title_wordcloud = WordCloud(height = 2000, width = 4000, background_color = "white", max_words = 200).generate(title_corpus)

# %%
type(title_wordcloud)
# Out:
# wordcloud.wordcloud.WordCloud

# %%
tagline_wordcloud = WordCloud(height = 2000, width = 4000, background_color = "white", max_words = 200).generate(tagline_corpus)
overview_wordcloud = WordCloud(height = 2000, width = 4000, background_color = "black", max_words = 200).generate(overview_corpus)

# %%
plt.figure(figsize=(14,7))
plt.imshow(title_wordcloud, interpolation = "bilinear")
plt.title("Movie Tagline Word Cloud")
plt.axis("off")
plt.show

plt.figure(figsize=(14,7))
plt.imshow(tagline_wordcloud, interpolation = "bilinear")
plt.title("Movie Tagline Word Cloud")
plt.axis("off")
plt.show

plt.figure(figsize=(14,7))
plt.imshow(overview_wordcloud, interpolation = "bilinear")
plt.title("Movie Overview Word Cloud")
plt.axis("off")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Let's find out whether the Franchises were successfull

# %%
df.columns
# Out:
# Index(['id', 'title', 'tagline', 'release_date', 'genres',
#        'belongs_to_collection', 'original_language', 'budget_musd',
#        'revenue_musd', 'production_companies', 'production_countries',
#        'vote_count', 'vote_average', 'popularity', 'runtime', 'overview',
#        'spoken_languages', 'poster_path', 'cast', 'cast_size', 'crew_size',
#        'director'],
#       dtype='object')

# %%
df['francise']=df.belongs_to_collection.notna()

# %%
df.francise.value_counts()
# Out:
# False    40228
# True      4463
# Name: francise, dtype: int64

# %%
df['ROI'] = df['revenue_musd']/df['budget_musd']

# %%
#standlone movies vs francise movies
df.groupby('francise').agg({'budget_musd':'mean', 'revenue_musd':'mean',
    'vote_count':'mean', 'vote_average':'mean', 'popularity':'mean', 'ROI':'median'})
# Out:
#           budget_musd  revenue_musd  vote_count  vote_average  popularity  ROI
# francise
# False           18.05         44.74       78.29          6.01        2.59 1.62
# True            38.32        165.71      412.39          5.96        6.25 3.71

# %%
df.belongs_to_collection.value_counts()
# Out:
# The Bowery Boys                  29
# Totò Collection                  27
# Zatôichi: The Blind Swordsman    26
# James Bond Collection            26
# The Carry On Collection          25
#                                  ..
# Salt and Pepper Collection        1
# Deadpool Collection               1
# Ant-Man Collection                1
# Elvira Collection                 1
# Red Lotus Collection              1
# Name: belongs_to_collection, Length: 1691, dtype: int64

# %%
franchies = df.groupby('belongs_to_collection').agg({
    'title': 'count','budget_musd': ['sum','mean'],'revenue_musd': ['sum','mean'],'ROI': 'median',
    'vote_average': 'mean', 'vote_count': 'mean', 'popularity': 'mean'})

# %%
franchies.head(10)
# Out:
#                                         title budget_musd       revenue_musd  \
#                                         count         sum  mean          sum
# belongs_to_collection
# ... Has Fallen Collection                   2      130.00 65.00       366.78
# 00 Schneider Filmreihe                      1        0.00   NaN         0.00
# 08/15 Collection                            1        0.00   NaN         0.00
# 100 Girls Collection                        2        0.00   NaN         0.00
# 101 Dalmatians (Animated) Collection        2        4.00  4.00       215.88
# 101 Dalmatians (Live-Action) Collection     2      139.00 69.50       504.30
# 12 Rounds Collection                        3       24.00 12.00        17.28
# 1920 Collection                             2        0.00   NaN         0.00
# 2 Days In... Collection                     2        8.00  8.00        21.43
# 2001 Maniacs Collection                     1        3.00  3.00         0.00
#
# ...

# %%
franchies.nlargest(20, ('title', 'count'))
# Out:
#                                        title budget_musd       revenue_musd  \
#                                        count         sum  mean          sum
# belongs_to_collection
# The Bowery Boys                           29        0.00   NaN         0.00
# Totò Collection                           27        0.00   NaN         0.00
# James Bond Collection                     26     1539.65 59.22      7106.97
# Zatôichi: The Blind Swordsman             26        0.00   NaN         0.00
# The Carry On Collection                   25        0.00   NaN         0.00
# Charlie Chan (Sidney Toler) Collection    21        0.00   NaN         0.00
# Pokémon Collection                        20      250.72 50.14       601.87
# Godzilla (Showa) Collection               16        2.81  0.56         0.00
# Charlie Chan (Warner Oland) Collection    15        0.00   NaN         0.00
# Dragon Ball Z (Movie) Collection          15        5.00  5.00       112.12
# ...

# %%
franchies.nlargest(20,('revenue_musd', 'sum'))
# Out:
#                                     title budget_musd        revenue_musd  \
#                                     count         sum   mean          sum
# belongs_to_collection
# Harry Potter Collection                 8     1280.00 160.00      7707.37
# Star Wars Collection                    8      854.35 106.79      7434.49
# James Bond Collection                  26     1539.65  59.22      7106.97
# The Fast and the Furious Collection     8     1009.00 126.12      5125.10
# Pirates of the Caribbean Collection     5     1250.00 250.00      4521.58
# Transformers Collection                 5      965.00 193.00      4366.10
# Despicable Me Collection                6      299.00  74.75      3691.07
# The Twilight Collection                 5      385.00  77.00      3342.11
# Ice Age Collection                      5      429.00  85.80      3216.71
# Jurassic Park Collection                4      379.00  94.75      3031.48
# ...

# %%
#10 top ROI franchies with minimum vote count 1000

franchies.head()
# Out:
#                                      title budget_musd       revenue_musd  \
#                                      count         sum  mean          sum
# belongs_to_collection
# ... Has Fallen Collection                2      130.00 65.00       366.78
# 00 Schneider Filmreihe                   1        0.00   NaN         0.00
# 08/15 Collection                         1        0.00   NaN         0.00
# 100 Girls Collection                     2        0.00   NaN         0.00
# 101 Dalmatians (Animated) Collection     2        4.00  4.00       215.88
#
#                                                ROI vote_average vote_count  \
#                                        mean median         mean       mean
# belongs_to_collection
# ... Has Fallen Collection            183.39   2.86         6.00    2333.00
# 00 Schneider Filmreihe                  NaN    NaN         6.50      16.00
# 08/15 Collection                        NaN    NaN         5.90       4.00
# ...

# %%
franchies.nlargest(10,('ROI', 'median'))
# Out:
#                                           title budget_musd      revenue_musd  \
#                                           count         sum mean          sum
# belongs_to_collection
# Blair Witch Collection                        3        5.06 2.53       293.17
# Super Size Me Collection                      1        0.07 0.07        28.58
# Open Water Collection                         2        1.33 0.67        54.67
# Bambi Collection                              2        0.86 0.86       267.45
# The Hills Have Eyes (Original) Collection     2        0.93 0.46        25.00
# Billy Jack Collection                         4        0.36 0.18        36.00
# Rocky Horror Collection                       2        1.20 1.20       112.89
# American Graffiti Collection                  2        3.28 1.64       155.01
# Cinderella Collection                         3       15.90 5.30       263.59
# Vixens Collection                             4        0.32 0.16         6.00
#
# ...

# %%
df2 = franchies[franchies['vote_count', 'mean'] >= 1000].nlargest(10, ('ROI', 'median'))

# %%
#lets find the overall profit for the above table.

df2['PROFIT(mill$)'] = df2[('budget_musd', 'sum')].add(df2[('revenue_musd', 'sum')])

# %%
df2.sort_values('PROFIT(mill$)', ascending = False)
# Out:
#                                 title budget_musd       revenue_musd         \
#                                 count         sum  mean          sum   mean
# belongs_to_collection
# Home Alone Collection               5       68.00 22.67       914.76 304.92
# The Lion King Collection            4       45.00 45.00       788.24 788.24
# The Conjuring Collection            2       53.00 26.50       638.17 319.09
# Aladdin Collection                  3       28.00 28.00       504.05 504.05
# The Mask Collection                 2      107.00 53.50       351.58 351.58
# The Jungle Book Collection          2       24.00 12.00       341.52 170.76
# Annabelle Collection                1        6.50  6.50       255.27 255.27
# Insidious Collection                3       16.50  5.50       201.31 100.66
# Sinister Collection                 2       13.00  6.50       130.59  65.30
# The Man With No Name Collection     3        2.00  0.67        35.50  11.83
#
# ...

# %% [markdown]
# ### Most Sucessful Directors

# %%
df.director
# Out:
# 0           John Lasseter
# 1            Joe Johnston
# 2           Howard Deutch
# 3         Forest Whitaker
# 4           Charles Shyer
#                ...
# 44686    Hamid Nematollah
# 44687            Lav Diaz
# 44688      Mark L. Lester
# 44689    Yakov Protazanov
# 44690       Daisy Asquith
# Name: director, Length: 44691, dtype: object

# %%
df.director.value_counts().head(10)
# Out:
# John Ford           66
# Michael Curtiz      65
# Werner Herzog       54
# Alfred Hitchcock    53
# Georges Méliès      49
# Woody Allen         49
# Jean-Luc Godard     46
# Sidney Lumet        46
# Charlie Chaplin     44
# Raoul Walsh         43
# Name: director, dtype: int64

# %%
plt.figure(figsize=(14,8))
df.director.value_counts().head(15).plot(kind='bar', fontsize = 12, color = "green", alpha = 0.5)
plt.title('Most Active Directors', fontsize= 20)
plt.ylabel('Number of Movies', fontsize = 15)
plt.show()

# %%
df.groupby('director').revenue_musd.sum().nlargest(20)
# Out:
# director
# Steven Spielberg    9256.62
# Peter Jackson       6528.24
# Michael Bay         6437.47
# James Cameron       5900.61
# David Yates         5334.56
# Christopher Nolan   4747.41
# Robert Zemeckis     4138.23
# Tim Burton          4032.92
# Ridley Scott        3917.53
# Chris Columbus      3866.84
# Roland Emmerich     3798.40
# Ron Howard          3714.15
# J.J. Abrams         3579.22
# Gore Verbinski      3575.34
# George Lucas        3341.55
# Sam Raimi           3193.79
# Francis Lawrence    3183.34
# Clint Eastwood      3100.68
# Bill Condon         3017.30
# Joss Whedon         2963.83
# Name: revenue_musd, dtype: float64

# %%
df.columns
# Out:
# Index(['id', 'title', 'tagline', 'release_date', 'genres',
#        'belongs_to_collection', 'original_language', 'budget_musd',
#        'revenue_musd', 'production_companies', 'production_countries',
#        'vote_count', 'vote_average', 'popularity', 'runtime', 'overview',
#        'spoken_languages', 'poster_path', 'cast', 'cast_size', 'crew_size',
#        'director', 'francise', 'ROI'],
#       dtype='object')

# %%
directors = df.groupby('director').agg({'title':'count',
                                        'vote_count':'sum',
                                        'vote_average' : 'mean'
                                        })

# %%
directors.head()
# Out:
#                      title  vote_count  vote_average
# director
#  Dale Trevillion\t       2        4.00          4.00
#  Davide Manuli           1       10.00          6.90
#  E.W. Swackhamer         1        5.00          5.90
#  Vitaliy Vorobyov        1        3.00          5.50
#  Yeon Sang-Ho            4     1039.00          6.60

# %%
directors[(directors['vote_count'] >= 10000) & (directors['title'] >= 10)].nlargest(20, 'vote_average')
# Out:
#                    title  vote_count  vote_average
# director
# Hayao Miyazaki        14    14700.00          7.70
# Christopher Nolan     11    67344.00          7.62
# Quentin Tarantino     10    45910.00          7.49
# Wes Anderson          10    11743.00          7.37
# David Fincher         10    37588.00          7.35
# Martin Scorsese       39    35541.00          7.22
# Peter Jackson         13    47571.00          7.14
# Joel Coen             17    18139.00          7.02
# James Cameron         11    33736.00          6.93
# Stanley Kubrick       16    18214.00          6.91
# James Mangold         10    16607.00          6.90
# Steven Spielberg      33    62266.00          6.89
# Danny Boyle           14    16504.00          6.87
# Guy Ritchie           10    19626.00          6.80
# Robert Zemeckis       19    37666.00          6.79
# Terry Gilliam         14    10049.00          6.76
# Tim Burton            21    36922.00          6.73
# ...

# %%
df.vote_average
# Out:
# 0       7.70
# 1       6.90
# 2       6.50
# 3       6.10
# 4       5.70
#         ...
# 44686   4.00
# 44687   9.00
# 44688   3.80
# 44689    NaN
# 44690    NaN
# Name: vote_average, Length: 44691, dtype: float64

# %%
df.genres = df.genres.astype(str)

# %%
df.loc[df.genres.str.contains('Horror')].groupby('director').revenue_musd.sum().nlargest(20)
# Out:
# director
# Paul W.S. Anderson    982.29
# James Wan             861.31
# Wes Craven            834.93
# Francis Lawrence      816.23
# Ridley Scott          689.00
# Marc Forster          531.87
# Steven Spielberg      500.10
# William Friedkin      466.40
# Darren Lynn Bousman   456.34
# M. Night Shyamalan    375.37
# Henry Joost           349.07
# David R. Ellis        348.74
# Adrian Lyne           346.11
# James DeMonaco        316.70
# Stephen Sommers       311.46
# Gore Verbinski        275.91
# Guillermo del Toro    261.63
# John R. Leonetti      255.27
# Fede Alvarez          254.64
# Jordan Peele          252.43
# Name: revenue_musd, dtype: float64

# %%
## Most successful actors

# %%
df.head()
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                              tagline release_date  \
# 0                                                NaN   1995-10-30
# 1          Roll the dice and unleash the excitement!   1995-12-15
# 2  Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3  Friends are the people who let you be yourself...   1995-12-22
# 4  Just When His World Is Back To Normal... He's ...   1995-02-10
#
#                      genres           belongs_to_collection original_language  \
# 0   Animation|Comedy|Family            Toy Story Collection                en
# 1  Adventure|Fantasy|Family                             NaN                en
# 2            Romance|Comedy       Grumpy Old Men Collection                en
# ...

# %%
df.set_index('id', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44691 entries, 862 to 461257
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  44691 non-null  object
#  1   tagline                20284 non-null  object
#  2   release_date           44657 non-null  datetime64[ns]
#  3   genres                 44691 non-null  object
#  4   belongs_to_collection  4463 non-null   object
#  5   original_language      44681 non-null  object
#  6   budget_musd            8854 non-null   float64
#  7   revenue_musd           7385 non-null   float64
#  8   production_companies   33356 non-null  object
#  9   production_countries   38835 non-null  object
#  10  vote_count             44691 non-null  float64
#  11  vote_average           42077 non-null  float64
#  12  popularity             44691 non-null  float64
#  13  runtime                43179 non-null  float64
# ...

# %%
df.cast
# Out:
# id
# 862       Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wal...
# 8844      Robin Williams|Jonathan Hyde|Kirsten Dunst|Bra...
# 15602     Walter Matthau|Jack Lemmon|Ann-Margret|Sophia ...
# 31357     Whitney Houston|Angela Bassett|Loretta Devine|...
# 11862     Steve Martin|Diane Keaton|Martin Short|Kimberl...
#                                 ...
# 439050              Leila Hatami|Kourosh Tahami|Elham Korda
# 111109    Angel Aquino|Perry Dizon|Hazel Orencio|Joel To...
# 67758     Erika Eleniak|Adam Baldwin|Julie du Page|James...
# 227506    Iwan Mosschuchin|Nathalie Lissenko|Pavel Pavlo...
# 461257                                                  NaN
# Name: cast, Length: 44691, dtype: object

# %%
df.cast.str.split('|', expand=True)
# Out:
#                      0                  1               2    \
# id
# 862            Tom Hanks          Tim Allen     Don Rickles
# 8844      Robin Williams      Jonathan Hyde   Kirsten Dunst
# 15602     Walter Matthau        Jack Lemmon     Ann-Margret
# 31357    Whitney Houston     Angela Bassett  Loretta Devine
# 11862       Steve Martin       Diane Keaton    Martin Short
# ...                  ...                ...             ...
# 439050      Leila Hatami     Kourosh Tahami     Elham Korda
# 111109      Angel Aquino        Perry Dizon   Hazel Orencio
# 67758      Erika Eleniak       Adam Baldwin   Julie du Page
# 227506  Iwan Mosschuchin  Nathalie Lissenko    Pavel Pavlov
# 461257               NaN                NaN             NaN
#
#                               3               4                  5    \
# id
# 862                    Jim Varney   Wallace Shawn  John Ratzenberger
# 8844               Bradley Pierce     Bonnie Hunt      Bebe Neuwirth
# ...

# %%
act = df.cast.str.split('|', expand =True)

# %%
act = act.stack().reset_index(level=1, drop=True).to_frame()

# %%
act.head()
# Out:
#                  0
# id
# 862      Tom Hanks
# 862      Tim Allen
# 862    Don Rickles
# 862     Jim Varney
# 862  Wallace Shawn

# %%
act.columns = ['Actor']

# %%
act.head()
# Out:
#              Actor
# id
# 862      Tom Hanks
# 862      Tim Allen
# 862    Don Rickles
# 862     Jim Varney
# 862  Wallace Shawn

# %%
act = act.merge(df[['title', 'revenue_musd', 'budget_musd', 'vote_average', 'popularity']],
          how = 'left', left_index = True, right_index = True)

# %%
act.Actor.nunique()
# Out:
# 201501

# %%
act.Actor.value_counts().head(20)
# Out:
# Bess Flowers          240
# Christopher Lee       148
# John Wayne            125
# Samuel L. Jackson     122
# Michael Caine         110
# Gérard Depardieu      109
# John Carradine        109
# Jackie Chan           108
# Donald Sutherland     108
# Frank Welker          107
# Robert De Niro        104
# Danny Trejo           101
# Steve Buscemi         101
# Irving Bacon           98
# John Goodman           97
# Christopher Walken     96
# Danny Glover           95
# John Hurt              93
# Susan Sarandon         92
# Dennis Hopper          92
# Name: Actor, dtype: int64

# %%
plt.figure(figsize=(16,7))
act.Actor.value_counts().head(20).plot(kind = 'bar', fontsize=12,
                                       color = 'orange', alpha = 0.6)
plt.title('Most Active Actors', fontsize = '18')
plt.ylabel('Number of films')
plt.show()

# %%
agg = act.groupby('Actor').agg(total_movies = ('title', 'count'),
                         total_revenue = ('revenue_musd', 'sum'),
                         average_revenue = ('revenue_musd', 'mean'),
                         average_rating = ('vote_average', 'mean'),
                         avg_popularity = ('popularity', 'mean')
                         )

# %%
agg.nlargest(10, 'total_movies')
# Out:
#                    total_movies  total_revenue  average_revenue  \
# Actor
# Bess Flowers                240         368.91            14.76
# Christopher Lee             148        9417.05           324.73
# John Wayne                  125         236.09            11.24
# Samuel L. Jackson           122       17109.62           213.87
# Michael Caine               110        8053.40           191.75
# Gérard Depardieu            109        1247.61            95.97
# John Carradine              109         255.84            19.68
# Donald Sutherland           108        5390.77           138.22
# Jackie Chan                 108        4699.19           146.85
# Frank Welker                107       13044.15           326.10
#
#                    average_rating  avg_popularity
# Actor
# Bess Flowers                 6.18            2.03
# Christopher Lee              5.91            4.75
# John Wayne                   5.71            3.09
# ...

# %%
agg.nlargest(10,'total_revenue')
# Out:
#                    total_movies  total_revenue  average_revenue  \
# Actor
# Stan Lee                     48       19414.96           647.17
# Samuel L. Jackson           122       17109.62           213.87
# Warwick Davis                34       13256.03           662.80
# Frank Welker                107       13044.15           326.10
# John Ratzenberger            46       12596.13           449.86
# Jess Harnell                 35       12234.61           611.73
# Hugo Weaving                 40       11027.58           459.48
# Ian McKellen                 44       11015.59           478.94
# Johnny Depp                  69       10653.76           217.42
# Alan Rickman                 45       10612.63           353.75
#
#                    average_rating  popularity
# Actor
# Stan Lee                     6.51       29.94
# Samuel L. Jackson            6.27       11.70
# Warwick Davis                6.29       13.09
# Frank Welker                 6.31        9.57
# ...

# %%
agg[agg.total_movies >= 10].nlargest(10, 'average_revenue')
# Out:
#                   total_movies  total_revenue  average_revenue  \
# Actor
# Gloria Stuart               18        1845.03          1845.03
# Keith Richards              23        2967.71           989.24
# Zoë Wanamaker               10         976.48           976.48
# James Cameron               12        1862.08           931.04
# Matthew Lewis               11        7915.31           879.48
# Luke de Woolfson            11        1720.67           860.34
# Yuri Lowenthal              17        1708.16           854.08
# Dominic Monaghan            11        3289.61           822.40
# Philip Ng                   10         821.71           821.71
# Peter Mayhew                11        4820.72           803.45
#
#                   average_rating  avg_popularity
# Actor
# Gloria Stuart               6.37            3.48
# Keith Richards              6.46            5.03
# Zoë Wanamaker               6.33            6.82
# James Cameron               7.06            4.69
# ...
